# %% [markdown]
# # 2024-1 Artificial Intelligence (01)
# ## Homework #4: Generative Adversarial Network
# ---
# Copyright (c) Prof. Jaehyeong Sim
#
# Department of Computer Science and Engineering
#
# College of Artificial Intelligence
#
# Ewha Womans University

# %% [markdown]
# ## Guideline
# ### Introduction
# > Here in this homework assignment 4, we will implement a GAN model to synthesis hand-digit numbers using TensorFlow Keras library.
#
# ### Your job
# > Please complete the code. You only have to write the parts marked as **### Please fill here**.
#
# ### Evaluation
# > More than 8 output images (out of 16) should contain recognizable numbers to get full credit.
#
# ### Submission guide
# 1. Please rename the completed skeleton file to ***STUDENT_ID*.ipynb**. Your own student ID goes to *STUDENT_ID*. For example, if your student ID is 2412345, the file name should be **2412345.ipynb**
# 2. Turn in it into the Ewha CyberCampus
#
# ⚠ If you doesn't follow the submission guide above, you will get **5 point deduction** from this homework score.

# %% [markdown]
# ### Importing necessary libraries

# %%
import tensorflow as tf
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time

# %% [markdown]
# ### Loading MNIST dataset

# %%
(train_images, train_labels), (_, _) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images - 127.5) / 127.5
BUFFER_SIZE = 60000
BATCH_SIZE = 256
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %% [markdown]
# ### Generator model
# The generator model has the following architecture:
# ![2023-1 AI - HW4 (1).png](data:image/png;base64,...)

# %%
def make_generator_model():

    model = tf.keras.Sequential()

    model.add(layers.Dense(7*7*256,  input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256) # 모델이 7x7x256 크기의 출력을 내놓도록 검증

    model.add(layers.Conv2DTranspose(
    filters=128,  # 필터 수
    kernel_size=(5, 5),  # 커널 크기
    strides=(1, 1),  # 스트라이드
    padding='SAME',  # 패딩 방식
    use_bias=False
))
    assert model.output_shape == (None, 7, 7, 128)

    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())


    model.add(layers.Conv2DTranspose(
    filters=64,  # 필터 수
    kernel_size=(5, 5),  # 커널 크기
    strides=(2, 2),  # 스트라이드
    padding='SAME',  # 패딩 방식
    use_bias=False
))

    assert model.output_shape == (None, 14, 14, 64)

    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Conv2DTranspose(
    filters=1,  # 필터 수
    kernel_size=(5, 5),  # 커널 크기
    strides=(2, 2),  # 스트라이드
    padding='SAME',  # 패딩 방식
))


    return model

# %% [markdown]
# ### Image generated from the untrained generator

# %%
generator = make_generator_model()

noise = tf.random.normal([1, 100])

generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %% [markdown]
# ### Discriminator model
# The discriminator model has the following architecture:
# ![2023-1 AI - HW4.png](data:image/png;base64,...)

# %%
def make_discriminator_model():

    model = tf.keras.Sequential()
    model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), strides=(2, 2), padding='SAME',
                                     input_shape=[28, 28, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(filters=128, kernel_size=(5, 5), strides=(2, 2), padding='SAME'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %% [markdown]
# ### Initial decision on the image

# %%
discriminator = make_discriminator_model()
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[-0.00237055]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ### Loss function and optimizer
# Come up with loss functions instead of log likelihood that we've learn in the lecture

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %%
def generator_loss(fake_output):
    loss = cross_entropy(tf.ones_like(fake_output), fake_output)
    return loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# ### Training loop

# %%
EPOCHS = 100
noise_dim = 100
num_examples_to_generate = 16

seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %%
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
def train(dataset, epochs):
  for epoch in range(epochs):
    start = time.time()

    for image_batch in dataset:
      train_step(image_batch)

    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

# %% [markdown]
# ### Do train

# %%
train(train_dataset, EPOCHS)
# Out:
# Time for epoch 1 is 13.452237844467163 sec
# Time for epoch 2 is 11.4619140625 sec
# Time for epoch 3 is 11.233412027359009 sec
# Time for epoch 4 is 11.107726812362671 sec
# Time for epoch 5 is 11.040671825408936 sec
# Time for epoch 6 is 11.05355978012085 sec
# Time for epoch 7 is 11.108242511749268 sec
# Time for epoch 8 is 11.186527967453003 sec
# Time for epoch 9 is 11.22462272644043 sec
# Time for epoch 10 is 11.243488311767578 sec
# Time for epoch 11 is 11.198380470275879 sec
# Time for epoch 12 is 11.14164686203003 sec
# Time for epoch 13 is 11.122159481048584 sec
# Time for epoch 14 is 11.124011754989624 sec
# Time for epoch 15 is 11.15265703201294 sec
# Time for epoch 16 is 11.16845703125 sec
# Time for epoch 17 is 11.177939176559448 sec
# Time for epoch 18 is 11.188752174377441 sec
# Time for epoch 19 is 11.175663471221924 sec
# Time for epoch 20 is 11.170797348022461 sec
# Time for epoch 21 is 11.169631481170654 sec
# Time for epoch 22 is 11.173787117004395 sec
# Time for epoch 23 is 11.232134819030762 sec
# Time for epoch 24 is 11.191540718078613 sec
# Time for epoch 25 is 11.166690111160278 sec
# Time for epoch 26 is 11.163847923278809 sec
# Time for epoch 27 is 11.167113780975342 sec
# Time for epoch 28 is 11.159345149993896 sec
# Time for epoch 29 is 11.162598133087158 sec
# Time for epoch 30 is 11.164816856384277 sec
# Time for epoch 31 is 11.16234564781189 sec
# Time for epoch 32 is 11.15902304649353 sec
# Time for epoch 33 is 11.15670895576477 sec
# Time for epoch 34 is 11.147745370864868 sec
# Time for epoch 35 is 11.150951623916626 sec
# Time for epoch 36 is 11.173080682754517 sec
# Time for epoch 37 is 11.165808916091919 sec
# Time for epoch 38 is 11.148459911346436 sec
# Time for epoch 39 is 11.1461763381958 sec
# Time for epoch 40 is 11.155147790908813 sec
# Time for epoch 41 is 11.149861335754395 sec
# Time for epoch 42 is 11.151967763900757 sec
# Time for epoch 43 is 11.154029130935669 sec
# Time for epoch 44 is 11.150093793869019 sec
# Time for epoch 45 is 11.143280982971191 sec
# Time for epoch 46 is 11.152706623077393 sec
# Time for epoch 47 is 11.184166193008423 sec
# Time for epoch 48 is 11.165801048278809 sec
# Time for epoch 49 is 11.177985191345215 sec
# Time for epoch 50 is 11.144808530807495 sec
# Time for epoch 51 is 11.151885986328125 sec
# Time for epoch 52 is 11.13189148902893 sec
# Time for epoch 53 is 11.135795831680298 sec
# Time for epoch 54 is 11.153554677963257 sec
# Time for epoch 55 is 11.156503200531006 sec
# Time for epoch 56 is 11.170533180236816 sec
# Time for epoch 57 is 11.177900552749634 sec
# Time for epoch 58 is 11.182011842727661 sec
# Time for epoch 59 is 11.165011644363403 sec
# Time for epoch 60 is 11.193161964416504 sec
# Time for epoch 61 is 11.166781425476074 sec
# Time for epoch 62 is 11.155099391937256 sec
# Time for epoch 63 is 11.141268968582153 sec
# Time for epoch 64 is 11.145643949508667 sec
# Time for epoch 65 is 11.154203414916992 sec
# Time for epoch 66 is 11.152346849441528 sec
# Time for epoch 67 is 11.159777164459229 sec
# Time for epoch 68 is 11.157863140106201 sec
# Time for epoch 69 is 11.202758312225342 sec
# Time for epoch 70 is 11.184319496154785 sec
# Time for epoch 71 is 11.158635377883911 sec
# Time for epoch 72 is 11.15611481666565 sec
# Time for epoch 73 is 11.167195558547974 sec
# Time for epoch 74 is 11.218975305557251 sec
# Time for epoch 75 is 11.183917760848999 sec
# Time for epoch 76 is 11.16128158569336 sec
# Time for epoch 77 is 11.160439491271973 sec
# Time for epoch 78 is 11.186723470687866 sec
# Time for epoch 79 is 11.163755893707275 sec
# Time for epoch 80 is 11.167995691299438 sec
# Time for epoch 81 is 11.162464618682861 sec
# Time for epoch 82 is 11.167004823684692 sec
# Time for epoch 83 is 11.163691282272339 sec
# Time for epoch 84 is 11.177391529083252 sec
# Time for epoch 85 is 11.165199756622314 sec
# Time for epoch 86 is 11.209923028945923 sec
# Time for epoch 87 is 11.247984886169434 sec
# Time for epoch 88 is 11.202434301376343 sec
# Time for epoch 89 is 11.202053785324097 sec
# Time for epoch 90 is 11.16842794418335 sec
# Time for epoch 91 is 11.16581416130066 sec
# Time for epoch 92 is 11.172272443771362 sec
# Time for epoch 93 is 11.171204328536987 sec
# Time for epoch 94 is 11.171751260757446 sec
# Time for epoch 95 is 11.171959400177002 sec
# Time for epoch 96 is 11.166144132614136 sec
# Time for epoch 97 is 11.170286655426025 sec
# Time for epoch 98 is 11.172866582870483 sec
# Time for epoch 99 is 11.184343576431274 sec
# Time for epoch 100 is 11.19626522064209 sec

# %% [markdown]
# ### Final images

# %%
predictions = generator(seed, training=False)

fig = plt.figure(figsize=(4,4))

for i in range(predictions.shape[0]):
    plt.subplot(4, 4, i+1)
    plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
    plt.axis('off')

plt.savefig('image.png')
plt.show()
